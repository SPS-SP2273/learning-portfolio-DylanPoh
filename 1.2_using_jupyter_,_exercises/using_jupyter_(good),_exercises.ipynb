# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Using Jupyter (Good), Exercises</span></div>

# %%
while True:
    print('*', end='')
# Out:
# **************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************
# ...

# %% [markdown]
# I did run the code and the output was: *********************************************************************************************************
#
# I interupted it by clicking the Interupt button in the top bar.

# %%
# print = 'PRINT'
print('Hello World')
# Out:
# Hello World

# %% [markdown]
# I did run the print = 'PRINT' code, and it caused an error when i ran the print('Hello World'), which continued even after deleting the first line of code.
#
# This is because the print command has been assigned 'PRINT', which overides its built-in function of printing out an output.
#
# I fixed this by clicking the Restart kernel button in the top bar.

# %%
# %%timeit
squares = [i**2 for i in range(10)]
# print(squares)
# Out:
# 556 ns ± 10.2 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %%
# %%timeit
squares = list()
for i in range(10):
    squares.append(i**2)
# print(squares)
# Out:
# 659 ns ± 6.72 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# 1. Both codes generates the list [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]
# 1. When using %%timeit, I ensured that I removed the print funcion to prevent it from spamming prints
# 1. Since the first code has a mean time per loop of 556ns, smaller than the second code of 659ns, thus the first code is more efficient. Since the first code has a standard deviation of 10.2ns, larger than the second code of 6.72ns, thus the first code has a greater spread in its efficiency from one run to another.

# %% [markdown]
# Additional Prompts:
# 1. If the logic for each of the code snippets from exercise 3 is the same, why is there a difference in the time taken?
#
# The list comprehension method (first code) is optimised to create lists, thus it is faster than the loop method.
#
# 2. The difference between the time taken is only a matter of seconds, if that. In what situations will this matter?
#
# It matters when you are generating very very large data sets, as the small time difference would add up.

# %% [markdown]
# ## Footnotes
